# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15316, done.
# remote: Total 15316 (delta 0), reused 0 (delta 0), pack-reused 15316
# Receiving objects: 100% (15316/15316), 13.72 MiB | 21.20 MiB/s, done.
# Resolving deltas: 100% (10406/10406), done.

# %%
# !sudo apt update
# !sudo apt install libopencv-dev python3-opencv -y
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic InRelease [242 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2367 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [11.3 MB]3m
# Get:7 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [607 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1431 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [26.7 kB]3m
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 Packages [1344 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [186 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/restricted amd64 Packages [13.5 kB]
# ...
